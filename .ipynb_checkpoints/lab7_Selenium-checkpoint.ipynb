# %%
from selenium.webdriver import Chrome
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup as bs

import requests
import os
import time
import pandas as pd
import re

# %%
def create_df(list_of_ads):
    data = {'Title': list_of_ads[0], 'Price': list_of_ads[1]}
    df = pd.DataFrame(data)
    df['Title'] = df['Title'].apply(lambda x: ''.join([str(i) for i in x]))
    df['Price'] = df['Price'].apply(lambda x: ''.join([''.join(re.findall(r'>([^<>]+)<', str(i))) for i in x]))
    return df

# %%
def parser(driver):
    html = driver.page_source
    soup = bs(html)
    elements = soup.find_all('h3', 
                             class_='styles-module-root-TWVKW styles-module-root-_KFFt styles-module-size_l-_oGDF styles-module-size_l_compensated-OK6a6 styles-module-size_l-hruVE styles-module-ellipsis-LKWy3 styles-module-weight_bold-Kpd5F stylesMarningNormal-module-root-OSCNq stylesMarningNormal-module-header-l-qvNIS')
    price = soup.find_all('strong', class_='styles-module-root-LIAav')
    photo = soup.find_all('div', class_='photo-slider-item-nKXVO photo-slider-item_visible-IHtR5 photo-slider-keepImageRatio-C5mWU')
    min_length = None
    if len(elements) > len(price):
        min_length = len(price)
    else:
        min_length = len(elements)
    
    elements = elements[len(elements) - min_length:]
    price = price[len(price) - min_length:]
    return elements, price

# %%
AVITO_URL = "https://www.avito.ru/"

# %%
def get_df_with_parse_value(keys):
    global AVITO_URL
    driver = webdriver.Chrome()
    driver.get(AVITO_URL)
    
    textarea = driver.find_element(By.CSS_SELECTOR, 'input.input-input-Zpzc1')
    textarea.send_keys(keys)
    
    submit_button = driver.find_element(By.CSS_SELECTOR, "button.desktop-15w37ob")
    submit_button.click()
    
    soup = parser(driver)
    df = create_df(soup)
    driver.quit()
    return df

# %%
df = get_df_with_parse_value('кошечка')

# %%
df
# Out:
#                                           Title                 Price
# 0       Сиделка медсестра с проживанием, услуги    от 3 000 ₽ за день
# 1    Стрижка и вычёсывание кошек. Груминг кошек    от 800 ₽ за услугу
# 2   Груминг кошек. Экспресс линька кошек. Вычес    от 500 ₽ за услугу
# 3                          Котята в добрые руки             Бесплатно
# 4                                         Кошка                   1 ₽
# 5                                         Кошка               3 000 ₽
# 6                                Кошка британка       Цена не указана
# 7                                         Кошка                   1 ₽
# 8                                         Кошка       Цена не указана
# 9       Золотой британский длинношерстный котик       Цена не указана
# 10                                        Кошка             Бесплатно
# 11                                 Кошка черная             Бесплатно
# 12                                  Кошка в дар             Бесплатно
# 13                                        Кошка             Бесплатно
# 14                  Шотландская вислоухая кошка       Цена не указана
# 15                                Кошечка в дар                   1 ₽
# 16                 Кошечка-богатка /сфинкс-браш                 350 ₽
# 17                                        Кошки             Бесплатно
# 18                                        Кошка       Цена не указана
# 19                         Шапка кошка с ушками               1 500 ₽
# 20                                        Кошка                   1 ₽
# 21                                        Кошка       Цена не указана
# 22                           Домик для кошки бу                 600 ₽
# 23      Стрижка кошек, экспресс линька. Груминг       700 ₽ за услугу
# 24                                      Кошечка       Цена не указана
# 25             Домик для кошки с когтеточкой бу                 300 ₽
# 26            Груминг кошек (прочтите описание)    от 800 ₽ за услугу
# 27                         Шкатулка гжель Кошка                 490 ₽
# 28                 Сиамская кошка в добрые руки             Бесплатно
# 29            Когтеточка для кошки. Реставрация  от 1 000 ₽ за услугу
# 30                                        Кошка             Бесплатно
# 31                                        Кошка             Бесплатно
# 32                                    Для кошек                 300 ₽
# 33                 Черная кошка красоточка Jane               1 000 ₽
# 34                Кошки в добрые руки бесплатно             Бесплатно
# 35                        Кошечка в добрые руки             Бесплатно
# 36                         Когтеточка для кошек               1 100 ₽
# 37                              Кошки бесплатно       Цена не указана
# 38                         Мягкая игрушка кошка                 200 ₽
# 39             Зоотакси, перевозка собак, кошек    от 500 ₽ за услугу
# 40                                        Кошка             Бесплатно
# 41                   Маска кошки для квадробики               1 200 ₽
# 42                            Шотландская кошка             Бесплатно
# 43          Груминг собак и кошек стрижка собак    от 200 ₽ за услугу
# 44                        Кошечка в добрые руки       Цена не указана
# 45                  Переноска для кошек и собак                 900 ₽
# 46                                        Кошки       Цена не указана
# 47                                Груминг кошек    от 700 ₽ за услугу
# 48  Зоотакси - перевозка собак и кошек по Перми       Цена договорная
# 49                   Два кота и кошка бесплатно             Бесплатно

# %%
# Out:
# []
